# %%
import numpy as np

# %%
random_sample = np.random.normal(loc=50,scale=6.25,size=(1,20))

# %%
sample_mean = np.mean(random_sample)

# %%
sample_mean
# Out:
# 49.17906364088972

# %%
sample_std = np.std(random_sample)

# %%
#sqrt((1/2N)*sum((xi**2)))

sample_m = np.sqrt(np.mean(random_sample**2)/2)

# %%
sample_m
# Out:
# 35.069357484400854

# %% [markdown]
# # Maximum_Likelihood_Estimation_Morning_Batch.pdf![image.png](attachment:image.png)

# %% [markdown]
# ## The formulas are used from the above pdf
# #### You can see the likelihood_fn_value_normal > likelihood_fn_value_rayliegh
# #### Which proved that the distribution is most probably the Normal.

# %% [markdown]
# #### You can also read the PDF  - Applied Statistics and Probability for Engineers
# #### The page 261 with title - Normal Distribution MLEs For $mu$ and $\sigma$

# %%
import math

# %%
exp_power = -np.sum((random_sample-sample_mean)**2)/(2*(sample_std**2))

# %%
likelihood_fn_value_normal = ((1/(np.sqrt(2*math.pi)*sample_std))**20)*np.exp(exp_power)

# %%
likelihood_fn_value_normal
# Out:
# 3.409418601797093e-29

# %%
exp_power_rayliegh = -np.sum((random_sample)**2)/(2*(sample_m**2))

# %%
likelihood_fn_value_rayliegh = (np.prod(random_sample)/sample_m**(2*20))*np.exp(exp_power_rayliegh)

# %%
likelihood_fn_value_rayliegh
# Out:
# 1.893645235220645e-37
